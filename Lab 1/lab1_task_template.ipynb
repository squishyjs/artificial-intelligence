# %% [markdown]
# # Task 1

# %% [markdown]
# Part 1: Define a function add(a,b) that returns the sum of a and b.

# %%
"""Task 1 - Part 1"""
def add(a, b):
    #"Return the sum of a and b"
    "*** YOUR CODE HERE ***"

# %%
#@title Part 1 Test: Run this cell to test your solution.
"""Test"""
import random
a = random.randint(0, 100)
b = random.randint(0, 100)
if add(a, b) == a + b:
    print ('Code Correct')
else:
    print ('Code Incorrect, Expected result: {}'.format(a + b))
# Out:
# Code Correct

# %% [markdown]
# Part 2: Write a simple program to take two integers from the user, calculate the sum of these two numbers using your function add(a,b) in Part 1 and print out the sum along with the two numbers.

# %%
"""Task 1 - Part 2"""
def input_add():
    #"Prompt the user to input the first integer"
    num1 = "*** YOUR CODE HERE ***"

    #"Prompt the user to input the second integer"
    num2 = "*** YOUR CODE HERE ***"

    #"Calculate the sum of num1 and num2 by calling your function add(a,b)"
    result = "*** YOUR CODE HERE ***"

    #"Return a tuple of result, num1, and num2 (result, num1, and num2)"
    "*** YOUR CODE HERE ***"

# Call this function to output the calculation result along with the first input num1 and second num2
"*** YOUR CODE HERE ***"
# Out:
# input the first integer: 10
# input the second integer: 20
# (30, 10, 20)

# %%
#@title #### Part 2 Test: Run this cell to test your solution.
"""Test"""
result, a, b = input_add()
if result == add(int(a),int(b)):
    print ("Code Correct")
else:
    print ('Code Incorrect, Expected result: {}'.format(add(int(a),int(b))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-299935491421> in <cell line: 3>()
#       1 #@title #### Part 2 Test: Run this cell to test your solution.
#       2 """Test"""
# ----> 3 result, a, b = input_add()
#       4 if result == add(int(a),int(b)):
#       5     print ("Code Correct")
#
# NameError: name 'input_add' is not defined

# %% [markdown]
# # Task 2

# %% [markdown]
# This task requires you to define a function, **loop_test(num)**, which takes an integer variable **num** as an argument and construct two lists of natural numbers starting from 1 using for-loop and while-loop, respectively. The default value of **num** is set to be 7.
#
# In this function, you are expected do the following steps:
#
# 1. Define two empty lists, named **a** and **b**.
# 3. Use a **for-loop** to add integers from **1** to **num** to the list **a** (Use the **append()** method to add elements to a list).
# 4. Use a **while-loop** to add integers from **1** to **num** to the list **b**.
#
# and return these two lists as a tuple of lists.

# %%
"""Task 2"""
def loop_test(num = 7):
    """
    Create two identical lists of natural numbers starting from 1 with the specified length.

    Parameters:
    num (int): The length of the list to create. Must be a positive integer.

    Special requirements: Use  for-loop and while-loop to build the lists

    Returns:
    tuple: A tuple of two lists of natural numbers starting from 1.
    """
    #"Define an empty list a"
    a = "*** YOUR CODE HERE ***"

    #"Define an empty list b"
    b = "*** YOUR CODE HERE ***"

    #"Use a for-loop to add integers from 1 to num to the list a"
    "*** YOUR CODE HERE ***"

    #"Use a while-loop to add integers from 1 to num to the list b"
    "*** YOUR CODE HERE ***"

    #"Return these two list as a tuple"
    "*** YOUR CODE HERE ***"

# %%
#@title #### Task 2 Test: Run this cell to test your solution.
"""Test"""
num = int (input ("Enter the size of this list: "))
solution_list = list(range(1, num + 1))
try:
    code_passed = True
    if loop_test(num)[0] == solution_list and loop_test(num)[1] == solution_list:
        pass
    else:
        code_passed = False
        print ('Code Incorrect, Expected result: {}'.format((solution_list, solution_list)))

    if code_passed:
        print ("Code Correct")
except:
    print ('loop_test() method returns wrong value')
# Out:
# Enter the size of this list: 10
# Code Correct

# %% [markdown]
# # Task 3

# %% [markdown]
# This task requires you to define a function, **condition_test(num)**, which takes an integer **num** as an argument and use condition statements **(if-elif)** and the function **range()**. The value of **num** should be greater than 2 but less than 100, and its default value is set to 10.
#
# Your task is to populate two lists: list **a** with even numbers, and list **b** with odd numbers, both within the range of **1** to **num** (inclusive). This should be done using a loop and conditional statements. At the end, return list **a** and **b** in a tuple.
#
# For example, if **num=7**, list **a** should be **[2, 4, 6]** and list **b** should be **[1, 3, 5, 7]**.

# %%
"""Task 3"""
def condition_test(num = 10):

    """
    Create a tuple of two lists using condition statement (if-elif) and range():
    - The first list contains even numbers between 1 and num + 1.
    - The second list contains odd numbers between 1 and num + 1.

    Parameters:
    num (int): The upper bound (inclusive) for generating even and odd numbers.

    Returns:
    tuple: A tuple containing two lists. The first list has even numbers, and the second list has odd numbers.
    """

    #"Define an empty list a"
    a = "*** YOUR CODE HERE ***"

    #"Define an empty list b"
    b = "*** YOUR CODE HERE ***"

    #"Use a for-loop and a if-elis condition statement to add the even integers and odd integers within (1-num) to List a and List b, respectively.
    "*** YOUR CODE HERE ***"

    #"Return these two list as (a,b)"
    "*** YOUR CODE HERE ***"

# %%
#@title #### Task 3 Test: Run this cell to test your solution.
"""Test"""
num = int (input ("Enter the size of this list: "))
if (num < 1) or (num > 100):
  print ("the number is out of range. The range is between 1 and 100 (inclusive). Try again")
  num = int (input ("Enter the size of this list: "))
even_numbers = [i for i in range(2, num + 1, 2)]  # Even numbers between 1 and num + 1
odd_numbers = [i for i in range(1, num + 1, 2)]   # Odd numbers between 1 and num + 1

try:
    code_passed = True
    if condition_test(num)[0] == even_numbers and condition_test(num)[1] == odd_numbers:
        pass
    else:
        code_passed = False
        print ('Code Incorrect, Expected result: {}'.format((even_numbers, odd_numbers)))

    if code_passed:
        print ("Code Correct")
except TypeError:
    print ('condition_test() method returns wrong value')
# Out:
# Enter the size of this list: 100
# Code Correct

# %% [markdown]
# # Task 4

# %% [markdown]
# In this exercise, you are required to create a function, **calculate_total_cost()**, that calculates the total cost of a list of fruits based on their individual unit prices and the quantities ordered.
#
# You will be given a dictionary, **fruitPrices**, where each key is a type of fruit and the corresponding value is the unit price of that fruit.
#
# For example, a dictionary **objectPrices** is represented as `{'obj1':price1, 'obj2': price2, 'obj3', price3}`, where `'obj1'` is a key and `price1` is its value.
#
# You will also be given a list, **orderList**, where each element is a tuple. The first element of the tuple is the type of fruit and the second element is the quantity ordered. For example, an order list can be expressed as `[('obj1', qty1), ('obj2', qty2), ('obj3', qty3)]`, where `('obj1', qty1)`,`('obj2', qty2)` and `('obj3', qty3)` are tuples.
#
# Your task is to extract the unit price for each fruit from the **fruitPrices** dictionary and the quantity of each fruit from the **OrderList**. Then, calculate the total cost for each type of fruit (unit price multiplied by quantity) and sum these costs to get the total cost of the fruit list.
#
# Using the above example, we will have `totalCost = price1 * qty1 + price2 * qty2 + price3 * qty3, where price1, price2 and price 3 can be extracted from fruitPrices dictionary and qty1, qty2 and qty3 can be extracted from orderList.

# %%
"""Task 4"""
# "Define a function to calculate the total cost of a fruit order in a fruit shop."

#"First, define data structures for the fruit prices and orders"
#"A list of tuples named 'orderList' is used to represent an order of fruits from this fruit store, where each element is a tuple containing a fruit's name and the quantity ordered. One example is shown below"
orderList = [('apples', 2.0), ('pears', 3.0), ('limes', 4.0)]

#"A dictionary named 'fruitPrices' is used to store the unit prices of different fruits in the fruit store. One example is shown below"
fruitPrices = {'apples': 2.00, 'oranges': 1.50, 'pears': 1.75,'limes': 0.75, 'strawberries': 1.00}

#"Then, define a function to calculate the total cost of a fruit order"
def calculate_total_cost(orderList, fruitPrices):
    #"Initialise a variable 'totalCost' to 0. This will be used to keep track of the total cost of the fruit order."
     totalCost = "*** YOUR CODE HERE ***"

    #"Use a for-loop to traverse the 'orderList', extracting the fruit's name and quantity and store them in two separate lists, fruitOrdered and qtyOrdered."
    fruitOrdered = []
    qtyOrdered = []

    "*** YOUR CODE HERE ***"

    #"Use a for-loop to traverse the 'fruitPrices' dictionary, extracting the pricces of fruits ordered by using the fruits ordered as the keys and save them into a new list 'prices'"
    prices = []
    "*** YOUR CODE HERE ***"

    # "For each fruit in the fruitOrdered list, calculate its cost by multiplying its quantity with its unit price, and add this cost to 'totalCost'.""
    for i in range (len(fruitOrdered)):
    "*** YOUR CODE HERE ***"

    #"Return the total cost.
    "*** YOUR CODE HERE ***"

# %%
#"Choose a fruit order in a fruit shop. In this task, two orders in one fruit shop are given as an example "
orderNo = int(input("choose an order number from 1 to 2. "))
if (orderNo ==1):
   orderList = [('apples', 2.0), ('pears', 3.0), ('limes', 4.0)]
   fruitPrices = {'apples': 2.00, 'oranges': 1.50, 'pears': 1.75, 'limes': 0.75, 'strawberries': 1.00}
elif (orderNo ==2):
   orderList = [ ('apples', 4.0), ('oranges',3.0), ('strawberries',2.0) ]
   fruitPrices = {'apples': 2.00, 'oranges': 1.50, 'pears': 1.75, 'limes': 0.75, 'strawberries': 1.00}
else:
   print("wrong order number (1-2). Try again")
   orderNo = int(input("choose an order number from 1 to 2. "))
# Out:
# choose an order number from 1 to 2. 2

# %%
#@title #### Task 4 Test: Run this cell to test your solution.
"""Test """
solution_cost=0
for fruit, qty in orderList:
  solution_cost += fruitPrices[fruit]*qty

code_passed = True
if calculate_total_cost(orderList, fruitPrices) == solution_cost:
    pass
else:
    code_passed = False
    print ('Code Incorrect, Expect result: {}'.format(solution_cost))

if code_passed:
    print ("Code Correct")
# Out:
# Code Correct

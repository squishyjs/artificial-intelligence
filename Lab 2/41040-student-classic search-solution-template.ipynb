# %% [markdown]
# ### Define a navigational search problem

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
import pandas as pd

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
import matplotlib.pyplot as plt

# %%
# Mount drive which is required when you need to read local files within this notebook
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/MyDrive/IntroAILab/Lab2
# Out:
# /content/gdrive/MyDrive/IntroAILab/Lab2

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
img = plt.imread('Romania-map.PNG')
plt.imshow(img)

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
df_cities = pd.read_csv('cities_coordinates.csv' )

df_cities
# Out:
#    LocationName  LocationX  LocationY
# 0          Arad         91        492
# 1     Bucharest        400        327
# 2       Craiova        253        288
# 3       Drobeta        165        299
# 4        Eforie        562        293
# 5       Fagaras        305        449
# 6       Giurgiu        375        270
# 7       Hirsova        534        350
# 8          Iasi        473        506
# 9         Lugoj        165        379
# 10      Mehadia        168        339
# 11        Neamt        406        537
# 12       Oradea        131        571
# 13      Pitesti        320        368
# 14      Rimnicu        233        410
# 15        Sibiu        207        457
# 16    Timisoara         94        410
# 17     Urziceni        456        350
# 18       Vaslui        509        444
# 19       Zerind        108        531

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
df_matrix = pd.read_csv("cities_correlation_matrix.csv")

df_matrix
# Out:
#     City Name  Arad  Bucharest  Craiova  Drobeta  Eforie  Fagaras  Giurgiu  \
# 0        Arad     0          0        0        0       0        0        0
# 1   Bucharest     0          0        0        0       0      211       90
# 2     Craiova     0          0        0      120       0        0        0
# 3     Drobeta     0          0      120        0       0        0        0
# 4      Eforie     0          0        0        0       0        0        0
# 5     Fagaras     0        211        0        0       0        0        0
# 6     Giurgiu     0         90        0        0       0        0        0
# 7     Hirsova     0          0        0        0      86        0        0
# 8        Iasi     0          0        0        0       0        0        0
# 9       Lugoj     0          0        0        0       0        0        0
# 10    Mehadia     0          0        0       75       0        0        0
# 11      Neamt     0          0        0        0       0        0        0
# 12     Oradea     0          0        0        0       0        0        0
# 13    Pitesti     0        101      138        0       0        0        0
# 14    Rimnicu     0          0      146        0       0        0        0
# 15      Sibiu   140          0        0        0       0       99        0
# 16  Timisoara   118          0        0        0       0        0        0
# 17   Urziceni     0         85        0        0       0        0        0
# 18     Vaslui     0          0        0        0       0        0        0
# 19     Zerind    75          0        0        0       0        0        0
#
#     Hirsova  Iasi  ...  Mehadia  Neamt  Oradea  Pitesti  Rimnicu  Sibiu  \
# 0       0.0     0  ...        0      0       0        0        0    140
# 1       0.0     0  ...        0      0       0      101        0      0
# 2       0.0     0  ...        0      0       0      138      146      0
# 3       0.0     0  ...       75      0       0        0        0      0
# 4      86.0     0  ...        0      0       0        0        0      0
# 5       0.0     0  ...        0      0       0        0        0     99
# 6       0.0     0  ...        0      0       0        0        0      0
# 7       0.0     0  ...        0      0       0        0        0      0
# 8       0.0     0  ...        0     87       0        0        0      0
# 9       0.0     0  ...       70      0       0        0        0      0
# 10      0.0     0  ...        0      0       0        0        0      0
# 11      0.0    87  ...        0      0       0        0        0      0
# 12      0.0     0  ...        0      0       0        0        0    151
# 13      0.0     0  ...        0      0       0        0       97      0
# 14      0.0     0  ...        0      0       0       97        0     80
# 15      0.0     0  ...        0      0     151        0       80      0
# 16      0.0     0  ...        0      0       0        0        0      0
# 17     98.0     0  ...        0      0       0        0        0      0
# 18      NaN    92  ...        0      0       0        0        0      0
# 19      0.0     0  ...        0      0      71        0        0      0
#
#     Timisoara  Urziceni  Vaslui  Zerind
# 0         118         0       0      75
# 1           0        85       0       0
# 2           0         0       0       0
# 3           0         0       0       0
# 4           0         0       0       0
# 5           0         0       0       0
# 6           0         0       0       0
# 7           0        98       0       0
# 8           0         0      92       0
# 9         111         0       0       0
# 10          0         0       0       0
# 11          0         0       0       0
# 12          0         0       0      71
# 13          0         0       0       0
# 14          0         0       0       0
# 15          0         0       0       0
# 16          0         0       0       0
# 17          0         0     142       0
# 18          0       142       0       0
# 19          0         0       0       0
#
# [20 rows x 21 columns]

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Task
# < Add you explanation of the following code statement>

cities = {}

# Task
# < Add you explanation of the following code statement>

name = df_cities["LocationName"]
locationX = df_cities["LocationX"]
locationY = df_cities["LocationY"]

# Task
# < Add you explanation of the following code statement>

location = zip(locationX, locationY)

# Task
# < Add you explanation of the following code statement>

for x1,x2 in zip(name, location):
    cities.update({x1:x2})

# View content of dictionary cities
cities
# Out:
# {'Arad': (91, 492),
#  'Bucharest': (400, 327),
#  'Craiova': (253, 288),
#  'Drobeta': (165, 299),
#  'Eforie': (562, 293),
#  'Fagaras': (305, 449),
#  'Giurgiu': (375, 270),
#  'Hirsova': (534, 350),
#  'Iasi': (473, 506),
#  'Lugoj': (165, 379),
#  'Mehadia': (168, 339),
#  'Neamt': (406, 537),
#  'Oradea': (131, 571),
#  'Pitesti': (320, 368),
#  'Rimnicu': (233, 410),
#  'Sibiu': (207, 457),
#  'Timisoara': (94, 410),
#  'Urziceni': (456, 350),
#  'Vaslui': (509, 444),
#  'Zerind': (108, 531)}

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Task
# < Add you explanation of the following line code>

neighbours=[]

# Task
# < Add you explanation of the following line code>

for i in range (df_matrix.shape[0]):
    # Task
    # < Add you explanation of the following line code>

    x = df_matrix.iloc[i,:]
    # Task
    # < Add you explanation of the following line code>

    relationKey=(x.iloc[0])

    # Task
    # < Add you explanation of the following line code>

    for j in range (1,df_matrix.shape[1]):
        # Task
        # < Add you explanation of the following line code>

        if (j>i and x.iloc[j] != 0 ):
          # Task
          # < Add you explanation of the following line code>

          temp_tuple = (relationKey,df_matrix.columns[j],x.iloc[j])
          # Task
          # < Add you explanation of the following line code>

          neighbours.append(temp_tuple)

# %%
# Display the above list and the numbers of its elements
print ('City neighbours data: {}'.format(neighbours))
print("\n{} elements in the list".format(len(neighbours)))
# Out:
# City neighbours data: [('Arad', 'Sibiu', 140), ('Arad', 'Timisoara', 118), ('Arad', 'Zerind', 75), ('Bucharest', 'Fagaras', 211), ('Bucharest', 'Giurgiu', 90), ('Bucharest', 'Pitesti', 101), ('Bucharest', 'Urziceni', 85), ('Craiova', 'Drobeta', 120), ('Craiova', 'Pitesti', 138), ('Craiova', 'Rimnicu', 146), ('Drobeta', 'Mehadia', 75), ('Eforie', 'Hirsova', 86.0), ('Fagaras', 'Sibiu', 99), ('Hirsova', 'Urziceni', 98), ('Iasi', 'Neamt', 87), ('Iasi', 'Vaslui', 92), ('Lugoj', 'Mehadia', 70), ('Lugoj', 'Timisoara', 111), ('Oradea', 'Sibiu', 151), ('Oradea', 'Zerind', 71), ('Pitesti', 'Rimnicu', 97), ('Rimnicu', 'Sibiu', 80), ('Urziceni', 'Vaslui', 142)]
#
# 23 elements in the list

# %%
# Task
# < Add you explanation of the following line code>

import networkx as nx

# %%
# Task
# < Add you explanation of the following line code>

G = nx.Graph()

# Task
# < Add you explanation of the following line code>

G.add_weighted_edges_from(neighbours)

# Task
# < Add you explanation of the following line code>

source='Arad'

# Task
# < Add you explanation of the following line code>

goal='Bucharest'

# %% [markdown]
# ## Implementation of a blind/uninformed search (Breadth first search (BFS)) algorithm and apply it to solve a problem.

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Import deque from python module collections. deque is a generalization of stacks and queues in Python.
from collections import deque

def bfs_path(G, start, goal):
    """Find a path from start to goal using breadth-First Search."""
    queue = deque([(start,[start])])
    visited = set()

    while queue:
       # for temp in queue:
       #   print (temp)
        (vertex, path) = queue.popleft()
        if vertex in visited:
            continue
        visited.add(vertex)
        #for temp in visited:
        #    print(temp)

        for neighbor in G[vertex]:
          #  print("neighbor is ", neighbor)
            if neighbor in visited:
                continue
            if neighbor == goal:
                return path + [neighbor]
            queue.append((neighbor, path + [neighbor]))

    return None  # Return None if no path is found

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Task
# < Add you explanation of the following line code>

path = bfs_path(G, source, goal)

# Task
# < Add you explanation of the following line code>

print("Path from source node  to goal node:", path)
# Out:
# Path from source node  to goal node: ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']

# %% [markdown]
# ## Implementation of a blind/uninformed search (Depth first search (DFS)) algorithm and apply it to solve a problem

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Import deque from python module collections. deque is a generalization of stacks and queues in Python.
from collections import deque

def dfs_path(G, start, goal):
    """Find a path from start to goal using Depth-First Search."""
    stack = deque([(start,[start])])
    visited = set()               # graph version

    while stack:
        #for i in range(len(stack)):
        #  print(stack[i])
        (vertex, path) = stack.pop()
        if vertex in visited:
            continue
        visited.add(vertex)
        #for temp in visited:
        #    print(temp)

        new_nodes = []
        for element in G[vertex]:
            new_nodes.append(element)
        new_nodes.reverse()
        for neighbor in new_nodes:
            #print("neighbor is ", neighbor)
            if neighbor in visited:
                continue
            if neighbor == goal:               # Ealy goal test which test whether a node is a goal node before add it to the frontier.
                return path + [neighbor]
            stack.append((neighbor, path + [neighbor]))

    return None  # Return None if no path is found

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Task
# < Add you explanation of the following line code>

path = dfs_path(G, source, goal)

# Task
# < Add you explanation of the following line code>

print("Path from source node to goal node using dfs algorithm is :", path)
# Out:
# Path from source node to goal node using dfs algorithm is : ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']

# %% [markdown]
# ## Implementation of the Uniform cost search (UCS) algorithm and apply it to solve a problem

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Define a class PriorityQueue

# Import heapq module which provides an implementation of the heap queue algorithm
import heapq

class PriorityQueue:
    def __init__(self):
        self._heap = []

    def push(self, item, priority):
        """
        Add an item to the priority queue with the given priority.

        Parameters:
            item: The item to add to the queue.
            priority: The priority of the item. Lower numbers indicate higher priority.
        """
        heapq.heappush(self._heap, (priority, item))

    def pop(self):
        """
        Remove and return the item with the highest priority (lowest priority number).

        Returns:
            The item with the highest priority.

        Raises:
            IndexError: If the priority queue is empty.
        """
        if self.is_empty():
            raise IndexError("pop from an empty priority queue")
        return heapq.heappop(self._heap)[1]

    def peek(self):
        """
        Return the item with the highest priority without removing it.

        Returns:
            The item with the highest priority.

        Raises:
            IndexError: If the priority queue is empty.
        """
        if self.is_empty():
            raise IndexError("peek from an empty priority queue")
        return self._heap[0][1]

    def is_empty(self):
        """
        Check if the priority queue is empty.

        Returns:
            True if the priority queue is empty, False otherwise.
        """
        return len(self._heap) == 0

    def __len__(self):
        """
        Return the number of items in the priority queue.

        Returns:
            The number of items in the queue.
        """
        return len(self._heap)

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
def ucs_path(G, start, goal):
    """Find a path from start to goal using breadth-First Search."""
    pq = PriorityQueue()
    pq.push((start,[start]),0)
    visited = set()

    while pq:
        (vertex, path) = pq.pop()
        if vertex in visited:
            continue
        visited.add(vertex)
        #for temp in visited:
           # print(temp)

        if vertex == goal:
                return path

        for neighbor in G[vertex]:
            #print("neighbor is ", neighbor)
            if neighbor in visited:
                continue
            pq.push((neighbor, path + [neighbor]),nx.path_weight(G, path + [neighbor],'weight'))

    return None  # Return None if no path is found

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Task
# < Add you explanation of the following line code>

path = ucs_path(G, source, goal)

# Task
# < Add you explanation of the following line code>

print("Path from source node  to goal node using UCS:", path)
# Out:
# Path from source node  to goal node using UCS: ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']

# %% [markdown]
# ## Implementation of an informed search algorithm (Greedy best first search (GBFS) agorithm) and apply it to solve a problem

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Define the PriorityQueue class if it has not been defined before

# Define a class PriorityQueue

# Import heapq module which provides an implementation of the heap queue algorithm
import heapq

class PriorityQueue:
    def __init__(self):
        self._heap = []

    def push(self, item, priority):
        """
        Add an item to the priority queue with the given priority.

        Parameters:
            item: The item to add to the queue.
            priority: The priority of the item. Lower numbers indicate higher priority.
        """
        heapq.heappush(self._heap, (priority, item))

    def pop(self):
        """
        Remove and return the item with the highest priority (lowest priority number).

        Returns:
            The item with the highest priority.

        Raises:
            IndexError: If the priority queue is empty.
        """
        if self.is_empty():
            raise IndexError("pop from an empty priority queue")
        return heapq.heappop(self._heap)[1]

    def peek(self):
        """
        Return the item with the highest priority without removing it.

        Returns:
            The item with the highest priority.

        Raises:
            IndexError: If the priority queue is empty.
        """
        if self.is_empty():
            raise IndexError("peek from an empty priority queue")
        return self._heap[0][1]

    def is_empty(self):
        """
        Check if the priority queue is empty.

        Returns:
            True if the priority queue is empty, False otherwise.
        """
        return len(self._heap) == 0

    def __len__(self):
        """
        Return the number of items in the priority queue.

        Returns:
            The number of items in the queue.
        """
        return len(self._heap)

# %%
# Define the heuristic function if it has not been defined before

# Task
# < Add you explanation of the following line code>

import numpy as np

# Task
# < Add you explanation of the following line code>

def heuristic(u, v):   # u and v are tuples
    return np.sqrt(sum((x - y) ** 2 for x, y in zip(u, v)))

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
def gbfs_path(G, start, goal):
    """Find a path from start to goal using breadth-First Search."""
    pq = PriorityQueue()
    pq.push((start,[start]),0)
    visited = set()

    while pq:
        (vertex, path) = pq.pop()
        if vertex in visited:
            continue
        visited.add(vertex)
        # for temp in visited:
        #    print(temp)

        if vertex == goal:
                return path

        for neighbor in G[vertex]:
           # print("neighbor is ", neighbor)
            if neighbor in visited:
                continue
            pq.push((neighbor, path + [neighbor]), heuristic(cities[neighbor],cities[goal]))

    return None  # Return None if no path is found

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Task
# < Add you explanation of the following line code>

path = gbfs_path(G, source, goal)

# Task
# < Add you explanation of the following line code>

print("Path from source node  to goal node using GBFS algorithm:", path)
# Out:
# Path from source node  to goal node: ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']

# %% [markdown]
# ## Implementation of an informed search algorithm (A star (A*) algorithm) and apply it to solve a problem

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
# Define the PriorityQueue class if it has not been defined before

class PriorityQueue:
    def __init__(self):
        self._heap = []

    def push(self, item, priority):
        """
        Add an item to the priority queue with the given priority.

        Parameters:
            item: The item to add to the queue.
            priority: The priority of the item. Lower numbers indicate higher priority.
        """
        heapq.heappush(self._heap, (priority, item))

    def pop(self):
        """
        Remove and return the item with the highest priority (lowest priority number).

        Returns:
            The item with the highest priority.

        Raises:
            IndexError: If the priority queue is empty.
        """
        if self.is_empty():
            raise IndexError("pop from an empty priority queue")
        return heapq.heappop(self._heap)[1]

    def peek(self):
        """
        Return the item with the highest priority without removing it.

        Returns:
            The item with the highest priority.

        Raises:
            IndexError: If the priority queue is empty.
        """
        if self.is_empty():
            raise IndexError("peek from an empty priority queue")
        return self._heap[0][1]

    def is_empty(self):
        """
        Check if the priority queue is empty.

        Returns:
            True if the priority queue is empty, False otherwise.
        """
        return len(self._heap) == 0

    def __len__(self):
        """
        Return the number of items in the priority queue.

        Returns:
            The number of items in the queue.
        """
        return len(self._heap)

# %%
# Define the heuristic function if it has not been defined before

# Task
# < Add you explanation of the following line code>

import numpy as np

# Task
# < Add you explanation of the following line code>

def heuristic(u, v):   # u and v are tuples
    return np.sqrt(sum((x - y) ** 2 for x, y in zip(u, v)))

# %% [markdown]
# Task:
# < Add your explanation of the code in the follwoing cell>

# %%
def my_astar_path(G, start, goal):
    """Find a path from start to goal using breadth-First Search."""
    pq = PriorityQueue()
    pq.push((start,[start]),0)
    visited = set()

    while pq:
        (vertex, path) = pq.pop()
        if vertex in visited:
            continue
        visited.add(vertex)
        #for temp in visited:
        #    print(temp)

        if vertex == goal:
                return path

        for neighbor in G[vertex]:
            #print("neighbor is ", neighbor)
            if neighbor in visited:
                continue
            pq.push((neighbor, path + [neighbor]), nx.path_weight(G, path + [neighbor],'weight')+heuristic(cities[neighbor],cities[goal]))

    return None  # Return None if no path is found

# %% [markdown]
# Apply A star algorithm to find a solution by calling the path-finding function.
# Two options:
# * Use self-defined path-finding function my_astar_path()
# * Use a built-in function in Networkx libary (nx)

# %%
# Task
# < Add you explanation of the following line code>

path = my_astar_path(G, source, goal)

# Task
# < Add you explanation of the following line code>

print("Path from source node  to goal node using A star algorithm:", path)
# Out:
# Path from source node  to goal node: ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']

# %%
# Redefine the heuristic function for using function astar_path() from nx library

# Task
# < Add you explanation of the following line code>

import numpy as np

# Task
# < Add you explanation of the following line code>

def heuristic(cn1, cn2):
    return np.sqrt(sum((x - y) ** 2 for x, y in zip(cities[cn1], cities[cn2])))

# %%
# Task
# < Add you explanation of the following line code>

path = nx.astar_path(G, source, goal, heuristic=heuristic)

# Task
# < Add you explanation of the following line code>

print("A* path:", path)
# Out:
# A* path: ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']
